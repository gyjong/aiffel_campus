# %% [markdown]
# ## Fixed Random Seed

# %%
import numpy as np
import random
import os

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## 데이터 불러오기 및 확인

# %%
import pandas as pd

train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

display(train.head(3))
display(test.head(3))
# Out:
#             ID  Age Gender                Education_Status Employment_Status  \
# 0  TRAIN_00000   63      M                    Middle (7-8)         Full-Time
# 1  TRAIN_00001   37      M  Associates degree (Vocational)         Full-Time
# 2  TRAIN_00002   58      F                   High graduate         Full-Time
#
#    Working_Week (Yearly)              Industry_Status  \
# 0                      4              Social Services
# 1                     52                Entertainment
# 2                     52  Manufacturing (Non-durable)
#
#                   Occupation_Status   Race Hispanic_Origin  ... Citizenship  \
# 0                          Services  White       All other  ...      Native
# 1                          Services  White       All other  ...      Native
# 2  Admin Support (include Clerical)  Black       All other  ...      Native
#
#   Birth_Country Birth_Country (Father) Birth_Country (Mother)  \
# 0            US                     US                     US
# 1            US                     US                     US
# 2            US                     US                     US
#
#                                     Tax_Status Gains Losses Dividends  \
# 0                                     Nonfiler     0      0         0
# 1                                       Single     0      0         0
# 2  Married Filling Jointly both under 65 (MFJ)  3411      0         0
#
#    Income_Status  Income
# 0        Unknown     425
# 1   Under Median       0
# 2   Under Median     860
#
# [3 rows x 23 columns]
#           ID  Age Gender  Education_Status         Employment_Status  \
# 0  TEST_0000   79      M       High Junior  Children or Armed Forces
# 1  TEST_0001   47      M  Elementary (5-6)  Children or Armed Forces
# 2  TEST_0002   18      F       High Junior  Children or Armed Forces
#
#    Working_Week (Yearly)              Industry_Status Occupation_Status  \
# 0                      0  Not in universe or children           Unknown
# 1                      0  Not in universe or children           Unknown
# 2                     52                       Retail          Services
#
#     Race Hispanic_Origin  ...  Household_Summary Citizenship Birth_Country  \
# 0  White       All other  ...        Householder      Native            US
# 1  White   Other Spanish  ...  Child 18 or older      Native            US
# 2  White       All other  ...  Child 18 or older      Native            US
#
#   Birth_Country (Father) Birth_Country (Mother) Tax_Status Gains Losses  \
# 0                Unknown                Unknown     Single     0      0
# 1                     US                     US   Nonfiler     0      0
# 2                     US                     US     Single     0      0
#
#    Dividends  Income_Status
# 0          0   Under Median
# 1          0   Under Median
# 2          0   Under Median
#
# [3 rows x 22 columns]

# %%
train.shape, test.shape
# Out:
# ((20000, 23), (10000, 22))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      20000 non-null  object
#  1   Age                     20000 non-null  int64
#  2   Gender                  20000 non-null  object
#  3   Education_Status        20000 non-null  object
#  4   Employment_Status       20000 non-null  object
#  5   Working_Week (Yearly)   20000 non-null  int64
#  6   Industry_Status         20000 non-null  object
#  7   Occupation_Status       20000 non-null  object
#  8   Race                    20000 non-null  object
#  9   Hispanic_Origin         20000 non-null  object
#  10  Martial_Status          20000 non-null  object
#  11  Household_Status        20000 non-null  object
#  12  Household_Summary       20000 non-null  object
#  13  Citizenship             20000 non-null  object
#  14  Birth_Country           20000 non-null  object
#  15  Birth_Country (Father)  20000 non-null  object
#  16  Birth_Country (Mother)  20000 non-null  object
#  17  Tax_Status              20000 non-null  object
#  18  Gains                   20000 non-null  int64
#  19  Losses                  20000 non-null  int64
#  20  Dividends               20000 non-null  int64
#  21  Income_Status           20000 non-null  object
#  22  Income                  20000 non-null  int64
# dtypes: int64(6), object(17)
# memory usage: 3.5+ MB

# %%
train.describe(include='all')
# Out:
#                  ID           Age Gender Education_Status  \
# count         20000  20000.000000  20000            20000
# unique        20000           NaN      2               17
# top     TRAIN_00000           NaN      F    High graduate
# freq              1           NaN  10472             6494
# mean            NaN     35.632500    NaN              NaN
# std             NaN     17.994414    NaN              NaN
# min             NaN      0.000000    NaN              NaN
# 25%             NaN     23.000000    NaN              NaN
# 50%             NaN     34.000000    NaN              NaN
# 75%             NaN     47.000000    NaN              NaN
# max             NaN     90.000000    NaN              NaN
#
#                Employment_Status  Working_Week (Yearly)  \
# count                      20000           20000.000000
# unique                         8                    NaN
# top     Children or Armed Forces                    NaN
# freq                       11142                    NaN
# mean                         NaN              34.943050
# std                          NaN              22.254592
# min                          NaN               0.000000
# 25%                          NaN               7.000000
# 50%                          NaN              52.000000
# 75%                          NaN              52.000000
# max                          NaN              52.000000
#
#                     Industry_Status Occupation_Status   Race Hispanic_Origin  \
# count                         20000             20000  20000           20000
# unique                           24                15      5              10
# top     Not in universe or children           Unknown  White       All other
# freq                           4688              4688  16845           17769
# mean                            NaN               NaN    NaN             NaN
# std                             NaN               NaN    NaN             NaN
# min                             NaN               NaN    NaN             NaN
# 25%                             NaN               NaN    NaN             NaN
# 50%                             NaN               NaN    NaN             NaN
# 75%                             NaN               NaN    NaN             NaN
# max                             NaN               NaN    NaN             NaN
#
#         ... Citizenship Birth_Country Birth_Country (Father)  \
# count   ...       20000         20000                  20000
# unique  ...           5            43                     43
# top     ...      Native            US                     US
# freq    ...       17825         17825                  16563
# mean    ...         NaN           NaN                    NaN
# std     ...         NaN           NaN                    NaN
# min     ...         NaN           NaN                    NaN
# 25%     ...         NaN           NaN                    NaN
# 50%     ...         NaN           NaN                    NaN
# 75%     ...         NaN           NaN                    NaN
# max     ...         NaN           NaN                    NaN
#
#        Birth_Country (Mother)                                   Tax_Status  \
# count                   20000                                        20000
# unique                     43                                            6
# top                        US  Married Filling Jointly both under 65 (MFJ)
# freq                    16594                                         8588
# mean                      NaN                                          NaN
# std                       NaN                                          NaN
# min                       NaN                                          NaN
# 25%                       NaN                                          NaN
# 50%                       NaN                                          NaN
# 75%                       NaN                                          NaN
# max                       NaN                                          NaN
#
#                Gains        Losses     Dividends  Income_Status        Income
# count   20000.000000  20000.000000  20000.000000          20000  20000.000000
# unique           NaN           NaN           NaN              3           NaN
# top              NaN           NaN           NaN   Under Median           NaN
# freq             NaN           NaN           NaN          13237           NaN
# mean      383.129500     40.202150    123.451450            NaN    554.565250
# std      4144.247487    279.182677   1206.949429            NaN    701.553155
# min         0.000000      0.000000      0.000000            NaN      0.000000
# 25%         0.000000      0.000000      0.000000            NaN      0.000000
# 50%         0.000000      0.000000      0.000000            NaN    500.000000
# 75%         0.000000      0.000000      0.000000            NaN    875.000000
# max     99999.000000   4356.000000  45000.000000            NaN   9999.000000
#
# [11 rows x 23 columns]

# %% [markdown]
# ## 데이터 전처리 1 : 학습 및 추론 데이터 설정

# %%
train_x = train.drop(columns=['ID', 'Income'])
train_y = train['Income']

test_x = test.drop(columns=['ID'])

# %% [markdown]
# ## 데이터 전처리 2 : 범주형 변수 수치화

# %%
from sklearn.preprocessing import LabelEncoder

encoding_target = list(train_x.dtypes[train_x.dtypes == "object"].index)

for i in encoding_target:
    le = LabelEncoder()
    
    # train과 test 데이터셋에서 해당 열의 모든 값을 문자열로 변환
    train_x[i] = train_x[i].astype(str)
    test_x[i] = test_x[i].astype(str)
    
    le.fit(train_x[i])
    train_x[i] = le.transform(train_x[i])
    
    # test 데이터의 새로운 카테고리에 대해 le.classes_ 배열에 추가
    for case in np.unique(test_x[i]):
        if case not in le.classes_: 
            le.classes_ = np.append(le.classes_, case)
    
    test_x[i] = le.transform(test_x[i])

# %%
train_x.head()
# Out:
#    Age  Gender  Education_Status  Employment_Status  Working_Week (Yearly)  \
# 0   63       1                15                  2                      4
# 1   37       1                 1                  2                     52
# 2   58       0                12                  2                     52
# 3   44       1                12                  2                     52
# 4   37       0                12                  2                     52
#
#    Industry_Status  Occupation_Status  Race  Hispanic_Origin  Martial_Status  \
# 0               20                 11     4                0               1
# 1                6                 11     4                0               4
# 2               11                  0     1                0               1
# 3               19                 12     4                0               0
# 4               19                 10     4                0               0
#
#    ...  Household_Summary  Citizenship  Birth_Country  Birth_Country (Father)  \
# 0  ...                  4            2             39                      39
# 1  ...                  4            2             39                      39
# 2  ...                  4            2             39                      39
# 3  ...                  4            2             39                      39
# 4  ...                  4            2             39                      39
#
#    Birth_Country (Mother)  Tax_Status  Gains  Losses  Dividends  Income_Status
# 0                      39           4      0       0          0              2
# 1                      39           5      0       0          0              1
# 2                      39           2   3411       0          0              1
# 3                      39           5      0       0          0              1
# 4                      39           0      0       0          0              2
#
# [5 rows x 21 columns]

# %%
train_y.head()
# Out:
# 0    425
# 1      0
# 2    860
# 3    850
# 4    570
# Name: Income, dtype: int64

# %%
test_x.head()
# Out:
#    Age  Gender  Education_Status  Employment_Status  Working_Week (Yearly)  \
# 0   79       1                 9                  0                      0
# 1   47       1                 7                  0                      0
# 2   18       0                 9                  0                     52
# 3   39       0                 1                  2                     30
# 4    6       1                 3                  0                      0
#
#    Industry_Status  Occupation_Status  Race  Hispanic_Origin  Martial_Status  \
# 0               14                 14     4                0               5
# 1               14                 14     4                8               5
# 2               19                 11     4                0               5
# 3               12                 11     4                0               1
# 4               14                 14     4                6               5
#
#    ...  Household_Summary  Citizenship  Birth_Country  Birth_Country (Father)  \
# 0  ...                  4            2             39                      40
# 1  ...                  0            2             39                      39
# 2  ...                  0            2             39                      39
# 3  ...                  7            2             39                      39
# 4  ...                  2            2             39                      39
#
#    Birth_Country (Mother)  Tax_Status  Gains  Losses  Dividends  Income_Status
# 0                      40           5      0       0          0              1
# 1                      39           4      0       0          0              1
# 2                      39           5      0       0          0              1
# 3                      39           2      0       0          0              2
# 4                      39           4      0       0          0              2
#
# [5 rows x 21 columns]

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train_x)
train_x = scaler.transform(train_x)
test_x = scaler.transform(test_x)

# %% [markdown]
# ## 모델 선정 및 학습

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor() 
model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## 예측 수행

# %%
preds = model.predict(test_x)

# %% [markdown]
# ## 제출양식에 예측결과 입력

# %%
submission = pd.read_csv('./sample_submission.csv')
submission['Income'] = preds
submission
# Out:
#              ID  Income
# 0     TEST_0000     0.0
# 1     TEST_0001     0.0
# 2     TEST_0002   500.0
# 3     TEST_0003   475.0
# 4     TEST_0004     0.0
# ...         ...     ...
# 9995  TEST_9995  1300.0
# 9996  TEST_9996   700.0
# 9997  TEST_9997   425.0
# 9998  TEST_9998     0.0
# 9999  TEST_9999   575.0
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## 예측결과 저장

# %%
submission.to_csv('./baseline_submission1.csv', index=False)
